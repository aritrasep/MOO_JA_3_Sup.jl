# %%
using Modof, DataFrames, DataFramesMeta, Match, PyCall, PyPlot

@pyimport seaborn as sns
sns.set_style("white")
sns.set_context("paper")
sns.set(font_scale=2.0)

plot_location = "../plots/"
# Out:
# WARNING: Method definition describe(AbstractArray) in module StatsBase at /home/aritra/.julia/v0.5/StatsBase/src/scalarstats.jl:560 overwritten in module DataFrames at /home/aritra/.julia/v0.5/DataFrames/src/abstractdataframe/abstractdataframe.jl:407.
# "../plots/"

# %%
single_thread_results = readtable("../results/UER4.csv")
single_thread_results_of_small_instances = readtable("../results/UER4_SI.csv")
single_thread_results_of_large_instances = readtable("../results/UER4_LI.csv")
# Out:
# 985×19 DataFrames.DataFrame
# │ Row │ Problem_Type │ Instance_Type │ Instance_ID    │ Correlation │
# ├─────┼──────────────┼───────────────┼────────────────┼─────────────┤
# │ 1   │ "BOAP"       │ "Hadi"        │ "10dat.txt"    │ 0.000869874 │
# │ 2   │ "BOAP"       │ "Hadi"        │ "10dat.txt"    │ 0.000869874 │
# │ 3   │ "BOAP"       │ "Hadi"        │ "10dat.txt"    │ 0.000869874 │
# │ 4   │ "BOAP"       │ "Hadi"        │ "10dat.txt"    │ 0.000869874 │
# │ 5   │ "BOAP"       │ "Hadi"        │ "10dat.txt"    │ 0.000869874 │
# │ 6   │ "BOAP"       │ "Hadi"        │ "10dat.txt"    │ 0.000869874 │
# │ 7   │ "BOAP"       │ "Hadi"        │ "10dat.txt"    │ 0.000869874 │
# │ 8   │ "BOAP"       │ "Hadi"        │ "10dat.txt"    │ 0.000869874 │
# │ 9   │ "BOAP"       │ "Hadi"        │ "10dat.txt"    │ 0.000869874 │
# │ 10  │ "BOAP"       │ "Hadi"        │ "10dat.txt"    │ 0.000869874 │
# │ 11  │ "BOAP"       │ "Hadi"        │ "10dat.txt"    │ 0.000869874 │
# ⋮
# ...

# %%
plt_performance_profiles(single_thread_results, [:Problem_Type, :Instance_Type, :Instance_ID], ["AUTO", "V1", "V2", "V3"])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f47a9f33da0>)
